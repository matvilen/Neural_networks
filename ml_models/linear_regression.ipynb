# %% [markdown]
# # Линейная регрессия

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Есть набор данных: знания о длине тормозного пути и скорости для трёх автомобилей.
# D=[10, 7, 12], V=[60, 50, 75]
# Напишите через запятую оценки коэффициентов линейной регрессии D на V с точностью до трёх знаков после точки.

# %%
D=[10, 7, 12]
V=[60, 50, 75]
B = (V.T@V)
D = VB
(xTx)(-1)xT * y
